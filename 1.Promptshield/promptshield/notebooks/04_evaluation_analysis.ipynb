# %% [markdown]
# # 04 — Evaluation Analysis
# Load results/classification_report.json and analyse errors.

# %%
import json
from pathlib import Path
r = json.loads(Path("../results/classification_report.json").read_text())
r

# %% [markdown]
# ## Per-class recall
# Cross-reference misclassifications with injection_class in the test split.
