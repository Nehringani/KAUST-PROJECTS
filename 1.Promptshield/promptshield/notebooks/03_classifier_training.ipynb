# %% [markdown]
# # 03 — Classifier Training (Google Colab)
# Runtime → Change runtime type → **T4 GPU**.
#
# Upload the folder  next to this notebook, or mount your Google Drive.

# %%
# !pip -q install transformers==4.38.0 datasets evaluate accelerate scikit-learn

# %%
# If you cloned the repo into Drive, cd into it. Otherwise upload src/ manually.
# from google.colab import drive; drive.mount("/content/drive")
# %cd /content/drive/MyDrive/promptshield

# %%
import sys, os
sys.path.insert(0, os.getcwd())
from src.models.trainer import main
main()

# %%
import json, pathlib
print(json.dumps(json.loads(pathlib.Path("results/classification_report.json").read_text()), indent=2))
