# %% [markdown]
# # 02 — Taxonomy Development
# See data/taxonomy/injection_taxonomy_v1.md for the canonical taxonomy.
# This notebook is a scratchpad for refining class definitions.

# %%
from src.data.preprocessor import CLASS_NAMES, SEVERITY
for k,v in CLASS_NAMES.items():
    print(k, v, SEVERITY[k])
