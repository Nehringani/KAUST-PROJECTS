# %% [markdown]
# # 01 — Data Exploration
# Explore the hand-crafted seed dataset and the augmented dataset.

# %%
import pandas as pd
df = pd.read_csv("../data/processed/augmented_dataset.csv")
df.head()

# %%
df["class_name"].value_counts()

# %%
df["soc_context"].value_counts()

# %%
df["text"].str.len().describe()
