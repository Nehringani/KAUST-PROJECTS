# %% [markdown]
# # JailbreakMap — manual exploration notebook
# Run the pipeline first: `python -m src.run_pipeline --synthetic`

# %%
import pandas as pd
df = pd.read_csv('../data/processed/jailbreakmap_dataset.csv')
df.head()

# %%
df['class'].value_counts()
